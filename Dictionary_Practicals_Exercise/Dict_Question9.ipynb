# %% [markdown]
# ***Question:- WAP in python to map two lists into dictionary with using zip function***

# %%
#maping two list in the format of dictionary
a=[1,2,3,4,5]
b=[6,7,8,9,10]
d=dict(zip(a,b))
d
# Out:
# {1: 6, 2: 7, 3: 8, 4: 9, 5: 10}
