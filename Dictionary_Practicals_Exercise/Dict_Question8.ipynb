# %% [markdown]
# ***Question:- WAP in python to map two lists into dictionary without using zip function***

# %%
#maping two lists into dictionary without zip function 
a=[1,2,3,4,5]
b=[6,7,8,9,10]
d=dict(map(lambda a,b:{a,b},a,b))
d
# Out:
# {1: 6, 2: 7, 8: 3, 9: 4, 10: 5}
