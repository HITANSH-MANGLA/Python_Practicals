# %% [markdown]
# **Question:-Wap in python to merge two dictionaries**

# %%
#merging two dictionaries
a={}
size=int(input("enter the size of first dictionary"))
for i in range(0,size):
  key=input("enter key")
  value=input("enter value")
  a[key]=value
b={}
size=int(input("enter the size of second array"))
for j in range(0,size):
  key=input("enter key")
  value=input("enter value")
  b[key]=value
a.update(b)
a
# Out:
# enter the size of first dictionary3
# enter key1
# enter value2
# enter key3
# enter value4
# enter key5
# enter value6
# enter the size of second array3
# enter key7
# enter value8
# enter key9
# enter value10
# enter key11
# enter value12
# {'1': '2', '11': '12', '3': '4', '5': '6', '7': '8', '9': '10'}
