# %% [markdown]
# **Question:-WAP in python to count the number of elements of array**

# %%
#counting the number of elements of array(non zero elements)
import numpy as np
a=np.array([1,2,3,4,5,6])
np.count_nonzero(a)
# Out:
# 6
