# %% [markdown]
# **Question:-WAP in python to count the occurence of each element**

# %%
#counting the frequency of each element in given array
import numpy as np
a=np.array([1,2,3,4,2,1])
arr_bins = np.bincount(a)
print(arr_bins)
len(arr_bins)
# Out:
# [0 2 2 1 1]
# 5
