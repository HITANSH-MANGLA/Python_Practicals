# %% [markdown]
# **Question:-WAP in python to replace python with php**

# %%
#replacing 'python' with 'php'
import numpy as np
a=np.array(['html','java','python','harry'])
print(a)
a[2]='php'
print("the updated array is",a)
# Out:
# ['html' 'java' 'python' 'harry']
# the updated array is ['html' 'java' 'php' 'harry']
